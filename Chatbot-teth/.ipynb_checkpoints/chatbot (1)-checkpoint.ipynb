# %%
# !pip install 

import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import tensorflow
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/content/drive/MyDrive/Odoo/intents.json').read()
intents = json.loads(data_file)
# Out:
# [nltk_data] Downloading package punkt to /home/tejas/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /home/tejas/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /home/tejas/nltk_data...
# 2022-07-05 14:25:20.334389: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-07-05 14:25:20.371947: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-05 14:25:20.371960: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 33 documents
# 8 classes ['about', 'complaint', 'createaccount', 'goodbye', 'greeting', 'help', 'name', 'thanks']
# 52 unique lemmatized words ["'s", 'a', 'about', 'account', 'an', 'anyone', 'are', 'bye', 'call', 'can', 'complaint', 'could', 'create', 'do', 'for', 'give', 'goodbye', 'hand', 'have', 'hay', 'hello', 'help', 'helpful', 'hey', 'hi', 'how', 'i', 'is', 'later', 'me', 'name', 'need', 'new', 'open', 'please', 'raise', 'see', 'service', 'should', 'support', 'thank', 'thanks', 'that', 'the', 'there', 'to', 'want', 'what', 'whats', 'who', 'you', 'your']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 7/7 [==============================] - 1s 7ms/step - loss: 2.1063 - accuracy: 0.0909
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1012 - accuracy: 0.1515
# Epoch 3/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0276 - accuracy: 0.2121
# Epoch 4/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8748 - accuracy: 0.2424
# Epoch 5/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8078 - accuracy: 0.3333
# Epoch 6/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7186 - accuracy: 0.4242
# Epoch 7/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5922 - accuracy: 0.4848
# Epoch 8/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6295 - accuracy: 0.3939
# Epoch 9/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4937 - accuracy: 0.4848
# Epoch 10/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3631 - accuracy: 0.5758
# Epoch 11/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2619 - accuracy: 0.5455
# Epoch 12/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0677 - accuracy: 0.7273
# Epoch 13/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9429 - accuracy: 0.6970
# Epoch 14/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1402 - accuracy: 0.6667
# Epoch 15/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9087 - accuracy: 0.7273
# Epoch 16/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8208 - accuracy: 0.8182
# Epoch 17/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7337 - accuracy: 0.8182
# Epoch 18/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7090 - accuracy: 0.8182
# Epoch 19/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7294 - accuracy: 0.8182
# Epoch 20/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6560 - accuracy: 0.8182
# Epoch 21/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5944 - accuracy: 0.8182
# Epoch 22/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6186 - accuracy: 0.7576
# Epoch 23/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5205 - accuracy: 0.9091
# Epoch 24/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4169 - accuracy: 0.9697
# Epoch 25/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6609 - accuracy: 0.7576
# Epoch 26/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5394 - accuracy: 0.7576
# Epoch 27/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5633 - accuracy: 0.8182
# Epoch 28/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4488 - accuracy: 0.8788
# Epoch 29/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3296 - accuracy: 0.9394
# Epoch 30/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3917 - accuracy: 0.9394
# Epoch 31/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3343 - accuracy: 0.9091
# Epoch 32/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2449 - accuracy: 1.0000
# Epoch 33/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2904 - accuracy: 0.8788
# Epoch 34/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3064 - accuracy: 0.9091
# Epoch 35/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2427 - accuracy: 0.9697
# Epoch 36/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3226 - accuracy: 0.9091
# Epoch 37/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2479 - accuracy: 0.9394
# Epoch 38/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2597 - accuracy: 0.9697
# Epoch 39/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2031 - accuracy: 0.9394
# Epoch 40/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2436 - accuracy: 0.9091
# Epoch 41/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3175 - accuracy: 0.8485
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2427 - accuracy: 0.9091
# Epoch 43/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9697
# Epoch 44/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1847 - accuracy: 0.9697
# Epoch 45/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2519 - accuracy: 0.9091
# Epoch 46/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2318 - accuracy: 0.9091
# Epoch 47/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0865 - accuracy: 1.0000
# Epoch 48/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2097 - accuracy: 0.9697
# Epoch 49/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1116 - accuracy: 0.9697
# Epoch 50/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2351 - accuracy: 0.9394
# Epoch 51/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 0.9697
# Epoch 52/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2154 - accuracy: 0.9394
# Epoch 53/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1749 - accuracy: 0.9697
# Epoch 54/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1382 - accuracy: 0.9394
# Epoch 55/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1663 - accuracy: 0.9394
# Epoch 56/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0854 - accuracy: 1.0000
# Epoch 57/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1068 - accuracy: 1.0000
# Epoch 58/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0826 - accuracy: 1.0000
# Epoch 59/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1325 - accuracy: 0.9697
# Epoch 60/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0739 - accuracy: 1.0000
# Epoch 61/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2313 - accuracy: 0.9394
# Epoch 62/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1500 - accuracy: 0.9697
# Epoch 63/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9697
# Epoch 64/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1732 - accuracy: 0.9697
# Epoch 65/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.9697
# Epoch 66/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1199 - accuracy: 1.0000
# Epoch 67/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 68/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9697
# Epoch 69/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 70/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 71/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0577 - accuracy: 0.9697
# Epoch 72/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 73/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 74/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 75/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1242 - accuracy: 0.9394
# Epoch 76/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 77/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1072 - accuracy: 0.9394
# Epoch 78/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1421 - accuracy: 0.9394
# Epoch 79/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9394
# Epoch 80/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 81/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0921 - accuracy: 0.9697
# Epoch 82/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 83/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0883 - accuracy: 0.9697
# Epoch 84/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0734 - accuracy: 0.9697
# Epoch 85/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 86/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0529 - accuracy: 1.0000
# Epoch 87/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 89/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 90/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1164 - accuracy: 0.9697
# Epoch 91/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1111 - accuracy: 0.9394
# Epoch 92/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 93/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1148 - accuracy: 0.9394
# Epoch 94/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0913 - accuracy: 1.0000
# Epoch 95/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1795 - accuracy: 0.9091
# Epoch 96/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 1.0000
# Epoch 97/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 99/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 100/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9697
# Epoch 101/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0569 - accuracy: 1.0000
# Epoch 102/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 103/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9697
# Epoch 104/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 0.9697
# Epoch 105/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 106/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 107/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 108/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 1.0000
# Epoch 109/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 110/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0732 - accuracy: 0.9697
# Epoch 111/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 112/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 113/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 1.0000
# Epoch 114/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 115/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0764 - accuracy: 0.9697
# Epoch 116/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0451 - accuracy: 0.9697
# Epoch 117/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9697
# Epoch 118/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 119/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 120/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0437 - accuracy: 0.9697
# Epoch 121/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 122/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 123/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0887 - accuracy: 0.9697
# Epoch 124/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 125/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 126/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 127/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0480 - accuracy: 1.0000
# Epoch 128/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 129/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 130/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 131/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9697
# Epoch 132/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 133/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 134/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 135/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0494 - accuracy: 0.9697
# Epoch 136/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 137/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 138/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 139/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 140/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 141/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 142/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 143/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 144/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 145/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 146/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 147/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 148/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 149/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0709 - accuracy: 1.0000
# Epoch 150/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 151/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0595 - accuracy: 0.9697
# Epoch 152/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 153/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 154/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 155/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1084 - accuracy: 0.9697
# Epoch 156/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 157/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 158/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 159/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 160/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 161/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 162/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 163/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 164/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 165/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 166/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 167/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 168/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 169/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 0.9697
# Epoch 170/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0719 - accuracy: 0.9697
# Epoch 171/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 172/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0877 - accuracy: 0.9697
# Epoch 173/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 174/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 175/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 176/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 177/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 178/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 179/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 180/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 181/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 182/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 183/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 184/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 185/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 186/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0393 - accuracy: 0.9697
# Epoch 187/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 188/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 189/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 190/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 191/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 192/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 0.9697
# Epoch 193/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 194/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 195/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 196/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 197/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 198/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 199/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 200/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('/content/drive/MyDrive/Odoo/intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-19-896b278da15a> in <module>()
#      19         ChatLog.yview(END)
#      20
# ---> 21 base = Tk()
#      22 base.title("Hello")
#      23 base.geometry("400x500")
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
